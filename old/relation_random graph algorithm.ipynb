# %%
import networkx as nx
import matplotlib.pyplot as plt

#Graph creation → Erdős–Rényi random graph algorithm (G(n, p))
#Node positions for plotting → Fruchterman–Reingold spring layout

# Create a graph
G = nx.erdos_renyi_graph(10, 0.3)

# Compute positions using spring layout
pos = nx.spring_layout(G)

# Draw the graph
nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray')
plt.show()

# %%
import osmnx as ox

# Tags for administrative boundaries
tags = {"place": ["suburb", "neighbourhood", "quarter", "borough"]}

# Correct method for version 2.0.3
gdf_places = ox.features_from_place("Athens", tags)
